# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
# create engine to hawaii.sqlite
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()

# reflect the tables
Base.prepare(autoload_with=engine)

# %%
# View all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Precipitation Analysis

# %%
# Inspect to determine shape of DB

# Create the inspector and connect it to the engine
inspector = inspect(engine)

# Use the inspector to print the column names within the 'measurement' table and its data types 
columns = inspector.get_columns('measurement')
print('Measurement columns:')
for column in columns:
    print(column["name"], column["type"])
columns = inspector.get_columns('station')

print('----------')

# Use the inspector to print the column names within the 'measurement' table and its data types 
print('Station columns:')
for column in columns:
    print(column["name"], column["type"])
# Out:
# Measurement columns:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT
# ----------
# Station columns:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
# Find the most recent date in the data set.
# Query the date column, order in descending order and select first result
most_recent_date = session.query(Measurement.date).order_by(Measurement.date.desc()).first()
print(most_recent_date[0])
# Out:
# 2017-08-23

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
# Starting from the most recent data point in the database. 

# Calculate the date one year from the last date in data set.
max_date = '2017-08-23'
min_date = '2016-08-23'

# Perform a query to retrieve the data and precipitation scores
one_year_prcp = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date <= max_date).filter(Measurement.date >= min_date).all()
one_year_prcp
# Out:
# [('2016-08-23', 0.0),
#  ('2016-08-24', 0.08),
#  ('2016-08-25', 0.08),
#  ('2016-08-26', 0.0),
#  ('2016-08-27', 0.0),
#  ('2016-08-28', 0.01),
#  ('2016-08-29', 0.0),
#  ('2016-08-30', 0.0),
#  ('2016-08-31', 0.13),
#  ('2016-09-01', 0.0),
#  ('2016-09-02', 0.0),
#  ('2016-09-03', 0.0),
#  ('2016-09-04', 0.03),
#  ('2016-09-05', None),
#  ('2016-09-06', None),
#  ('2016-09-07', 0.05),
#  ('2016-09-08', 0.0),
#  ('2016-09-09', 0.03),
#  ('2016-09-10', 0.0),
#  ('2016-09-11', 0.05),
#  ('2016-09-12', 0.0),
#  ('2016-09-13', 0.02),
#  ('2016-09-14', 1.32),
#  ('2016-09-15', 0.42),
#  ('2016-09-16', 0.06),
#  ('2016-09-17', 0.05),
#  ('2016-09-18', 0.0),
#  ('2016-09-19', 0.0),
#  ('2016-09-20', 0.0),
#  ('2016-09-21', 0.0),
#  ('2016-09-22', 0.02),
#  ('2016-09-23', 0.0),
#  ('2016-09-24', 0.0),
#  ('2016-09-25', 0.0),
#  ('2016-09-26', 0.06),
#  ('2016-09-27', 0.02),
#  ('2016-09-28', 0.0),
#  ('2016-09-29', 0.0),
#  ('2016-09-30', 0.0),
#  ('2016-10-01', 0.0),
# ...

# %%
# Save the query results as a Pandas DataFrame. Explicitly set the column names.
prcp_df = pd.DataFrame(one_year_prcp, columns = ["Date", "Precipitation (Inches)"])

# Clean data: fill NaN columns with 0
prcp_df = prcp_df.fillna({'Precipitation (Inches)': 0})

# Sort the DataFrame by date (sparkbyexamples.com)
prcp_df.sort_values(by='Date', inplace = True)

# Display DataFrame
prcp_df.head()
# Out:
#             Date  Precipitation (Inches)
# 0     2016-08-23                    0.00
# 1009  2016-08-23                    0.00
# 1529  2016-08-23                    1.79
# 704   2016-08-23                    0.05
# 361   2016-08-23                    0.15

# %%
# Use Pandas Plotting with Matplotlib to plot the data
figure_1 = prcp_df.plot(x='Date', y='Precipitation (Inches)', 
                        rot=45, ylim=(0,7.5),
                        title= "Precipitation Over 12 Months",
                        xlabel = "Date",
                        ylabel = "Inches"
                        ).legend(loc='best')
plt.show()

# %%
# Use Pandas to calculate the summary statistics for the precipitation data
prcp_df.describe()
# Out:
#        Precipitation (Inches)
# count             2230.000000
# mean                 0.160664
# std                  0.442067
# min                  0.000000
# 25%                  0.000000
# 50%                  0.010000
# 75%                  0.110000
# max                  6.700000

# %% [markdown]
# # Exploratory Station Analysis

# %%
# Design a query to calculate the total number of stations in the dataset
total_stations = session.query(Station.station).count()
total_stations
# Out:
# 9

# %%
# Design a query to find the most active stations (i.e. which stations have the most rows?)

# List the stations and their counts in descending order.
session.query(Measurement.station, func.count(Measurement.station)).\
    order_by(func.count(Measurement.station).desc()).\
    group_by(Measurement.station).all()
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# Using the most active station id from the previous query, calculate the lowest, highest, and average temperature.

# Print most active station ID based off of previous query
print(f"Most active station: USC00519281")

# Query min function for lowest temperature
min = session.query(func.min(Measurement.tobs)).filter(Measurement.station == 'USC00519281').all()
print(f"Lowest temperature: {min[0]}")

# Query max function for highest temparture
max = session.query(func.max(Measurement.tobs)).filter(Measurement.station == 'USC00519281').all()
print(f"Highest temperature: {max[0]}")

# Query avg function for average temperature
avg = session.query(func.avg(Measurement.tobs)).filter(Measurement.station == 'USC00519281').all()
print(f"Average temperature: {avg[0]}")
# Out:
# Most active station: USC00519281
# Lowest temperature: (54.0,)
# Highest temperature: (85.0,)
# Average temperature: (71.66378066378067,)

# %%
# Using the most active station id
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram

#Query last 12 months of temperature observation data at USC00519281
one_year_station = session.query(Measurement.date, Measurement.tobs).filter(Measurement.date <= max_date).filter(Measurement.date >= min_date).filter(Measurement.station == 'USC00519281').all()
one_year_station
# Out:
# [('2016-08-23', 77.0),
#  ('2016-08-24', 77.0),
#  ('2016-08-25', 80.0),
#  ('2016-08-26', 80.0),
#  ('2016-08-27', 75.0),
#  ('2016-08-28', 73.0),
#  ('2016-08-29', 78.0),
#  ('2016-08-30', 77.0),
#  ('2016-08-31', 78.0),
#  ('2016-09-01', 80.0),
#  ('2016-09-02', 80.0),
#  ('2016-09-03', 78.0),
#  ('2016-09-04', 78.0),
#  ('2016-09-05', 78.0),
#  ('2016-09-06', 73.0),
#  ('2016-09-07', 74.0),
#  ('2016-09-08', 80.0),
#  ('2016-09-09', 79.0),
#  ('2016-09-10', 77.0),
#  ('2016-09-11', 80.0),
#  ('2016-09-12', 76.0),
#  ('2016-09-13', 79.0),
#  ('2016-09-14', 75.0),
#  ('2016-09-15', 79.0),
#  ('2016-09-16', 78.0),
#  ('2016-09-17', 79.0),
#  ('2016-09-18', 78.0),
#  ('2016-09-19', 78.0),
#  ('2016-09-20', 76.0),
#  ('2016-09-21', 74.0),
#  ('2016-09-22', 77.0),
#  ('2016-09-23', 78.0),
#  ('2016-09-24', 79.0),
#  ('2016-09-25', 79.0),
#  ('2016-09-26', 77.0),
#  ('2016-09-27', 80.0),
#  ('2016-09-28', 78.0),
#  ('2016-09-29', 78.0),
#  ('2016-09-30', 78.0),
#  ('2016-10-01', 77.0),
# ...

# %%
# Save the query results as a Pandas DataFrame and set the column names
station_df = pd.DataFrame(one_year_station, columns = ["Date", "Temperature (F)"])

# Display DataFrame
station_df.head()
# Out:
#          Date  Temperature (F)
# 0  2016-08-23             77.0
# 1  2016-08-24             77.0
# 2  2016-08-25             80.0
# 3  2016-08-26             80.0
# 4  2016-08-27             75.0

# %%
# Plot the results as a histogram
figure_2 = station_df.plot.hist(title='Temperature Over 12 Months at USC00519281', bins=12)
figure_2.set_xlabel("Temperature (F)")
plt.show()

# %% [markdown]
# # Close Session

# %%
# Close Session
session.close()
